# %%
import pandas as pd

# %%
df = pd.read_csv("mushrooms.csv")

# %%
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
df.shape
# Out:
# (8124, 23)

# %%
df["class"]
# Out:
# 0       p
# 1       e
# 2       e
# 3       p
# 4       e
#        ..
# 8119    e
# 8120    e
# 8121    e
# 8122    p
# 8123    e
# Name: class, Length: 8124, dtype: object

# %%
df.iloc[3:28]
# Out:
#    class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 3      p         x           y         w       t    p               f
# 4      e         x           s         g       f    n               f
# 5      e         x           y         y       t    a               f
# 6      e         b           s         w       t    a               f
# 7      e         b           y         w       t    l               f
# 8      p         x           y         w       t    p               f
# 9      e         b           s         y       t    a               f
# 10     e         x           y         y       t    l               f
# 11     e         x           y         y       t    a               f
# 12     e         b           s         y       t    a               f
# 13     p         x           y         w       t    p               f
# 14     e         x           f         n       f    n               f
# ...

# %%
df.loc[3:23]
# Out:
#    class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 3      p         x           y         w       t    p               f
# 4      e         x           s         g       f    n               f
# 5      e         x           y         y       t    a               f
# 6      e         b           s         w       t    a               f
# 7      e         b           y         w       t    l               f
# 8      p         x           y         w       t    p               f
# 9      e         b           s         y       t    a               f
# 10     e         x           y         y       t    l               f
# 11     e         x           y         y       t    a               f
# 12     e         b           s         y       t    a               f
# 13     p         x           y         w       t    p               f
# 14     e         x           f         n       f    n               f
# ...

# %%
df.loc['class':'gill-color']
# Out:
# Empty DataFrame
# Columns: [class, cap-shape, cap-surface, cap-color, bruises, odor, gill-attachment, gill-spacing, gill-size, gill-color, stalk-shape, stalk-root, stalk-surface-above-ring, stalk-surface-below-ring, stalk-color-above-ring, stalk-color-below-ring, veil-type, veil-color, ring-number, ring-type, spore-print-color, population, habitat]
# Index: []
#
# [0 rows x 23 columns]

# %%
columns=list(df.columns)

# %%
df.columns[3]
# Out:
# 'cap-color'

# %%
b=df["class"]=="p"

# %%
b
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 8119    False
# 8120    False
# 8121    False
# 8122     True
# 8123    False
# Name: class, Length: 8124, dtype: bool

# %%
b.shape
# Out:
# (8124,)

# %%
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
df["class"].min
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.min of 0       p
# 1       e
# 2       e
# 3       p
# 4       e
#        ..
# 8119    e
# 8120    e
# 8121    e
# 8122    p
# 8123    e
# Name: class, Length: 8124, dtype: object>

# %%
pb=df[b]

# %%
pb
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 3        p         x           y         w       t    p               f
# 8        p         x           y         w       t    p               f
# 13       p         x           y         w       t    p               f
# 17       p         x           s         n       t    p               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8114     p         f           y         c       f    m               a
# 8116     p         k           y         n       f    s               f
# 8117     p         k           s         e       f    y               f
# 8118     p         k           y         n       f    f               f
# 8122     p         k           y         n       f    y               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
b=df["odor"]=="m"

# %%
b
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8119    False
# 8120    False
# 8121    False
# 8122    False
# 8123    False
# Name: odor, Length: 8124, dtype: bool

# %%
bm=df[b]

# %%
bm
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 6415     p         x           y         e       f    m               f
# 6668     p         k           y         c       f    m               a
# 6855     p         k           y         n       f    m               f
# 6945     p         f           y         e       f    m               a
# 6991     p         k           y         e       f    m               f
# 7034     p         k           y         c       f    m               f
# 7065     p         x           y         n       f    m               a
# 7091     p         f           y         n       f    m               f
# 7100     p         x           y         c       f    m               a
# 7111     p         k           y         n       f    m               a
# 7146     p         f           y         c       f    m               f
# 7166     p         f           y         n       f    m               f
# ...

# %%
columns
# Out:
# ['class',
#  'cap-shape',
#  'cap-surface',
#  'cap-color',
#  'bruises',
#  'odor',
#  'gill-attachment',
#  'gill-spacing',
#  'gill-size',
#  'gill-color',
#  'stalk-shape',
#  'stalk-root',
#  'stalk-surface-above-ring',
#  'stalk-surface-below-ring',
#  'stalk-color-above-ring',
#  'stalk-color-below-ring',
#  'veil-type',
#  'veil-color',
#  'ring-number',
#  'ring-type',
#  'spore-print-color',
#  'population',
#  'habitat']
